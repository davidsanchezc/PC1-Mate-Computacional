# %%
def final_time(star_time,period_time):
    st=star_time.split(":")
    horas=int(st[0])
    minu=int(st[1])
    period_time=int(period_time)
    print(period_time)
    minu=minu+period_time
    m=int(minu/60)
    minu=minu%60
    horas=horas+m
    horas=horas%24
    print(horas,":",minu)

# %%
final_time("12:17","59")
# Out:
# 59
# 13 : 16

# %%
final_time("3:57","1379")
# Out:
# 1379
# 2 : 56

# %%
final_time("1:35","3578")
# Out:
# 3578
# 13 : 13

# %%
final_time("13:59","-13593")
# Out:
# -13593
# 4 : 26
